# %% [markdown]
# # T02- Visualización
# ## Luis Alejandro Ledesma Mujica
# ### 28/ago/2024

# %% [markdown]
# #### Graficar funciones

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
import pandas as pd

x = np.linspace (-20, 25, 100)
y = x**2 - 4*x + 2
plt.plot(x,y)

# %%
x = np.linspace (-20, 20, 100)
y = np.sin(3 * x)
plt.plot(x,y)

# %%
x = np.linspace (-1, 20, 100)
y = np.exp(2 * x) - 3
plt.plot(x,y)

# %%
x = np.linspace (-25, 25, 100)
y = np.sqrt((x**2)-4)
plt.plot(x,y)
# Out:
# /var/folders/ld/zrrztc917_n06qvr1khsj0rc0000gn/T/ipykernel_31814/503809836.py:2: RuntimeWarning: invalid value encountered in sqrt
#   y = np.sqrt((x**2)-4)

# %%
x = np.linspace (0, 15, 100)
y = np.cos(x+(np.pi/4))
plt.plot(x,y)

# %% [markdown]
# ### Graficar grupos de funciones

# %%
x = np.linspace (-10, 10, 100)
y = (2*x) + 1
y2 = - x + 4
y3 = x**2
plt.plot(x, y)
plt.plot(x, y2)
plt.plot(x, y3)

# %%
x = np.linspace (-10, 10, 100)
y = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y)
plt.plot(x, y2)

# %% [markdown]
# ### Función que grafique
# $$ f(x) = sen(\alpha x) $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

def funcion(x1, x2, n, a, b, k):
    x = np.linspace(x1, x2, n)
    alpha = np.linspace(a, b, k)
    graf = plt.figure()

    
    for alpha in alpha:
        y = np.sin(alpha * x)
        y.plot(x,y)


funcion(0, 2*np.pi, 1000, 1, 3, 3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[135], line 15
#      11         y = np.sin(alpha * x)
#      12         y.plot(x,y)
# ---> 15 funcion(0, 2*np.pi, 1000, 1, 3, 3)
#
# Cell In[135], line 12, in funcion(x1, x2, n, a, b, k)
#      10 for alpha in alpha:
#      11     y = np.sin(alpha * x)
# ---> 12     y.plot(x,y)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'
